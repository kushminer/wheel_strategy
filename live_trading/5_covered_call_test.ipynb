# %% [markdown]
# # Covered Call — Integration Test Notebook
#
# Tests the full CC lifecycle on the paper account:
# 1. Buy shares of random S&P 500 tickers
# 2. Detect stock positions via CC manager
# 3. Select and sell covered calls
# 4. Monitor active CCs
# 5. Clean up
#
# **Run cell-by-cell during market hours.**

# %%
# Imports
import random
import json
import asyncio
import time

from dotenv import load_dotenv
load_dotenv(override=True)

from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce

from csp.config import StrategyConfig
from csp.clients import AlpacaClientManager
from csp.data.vix import VixDataFetcher
from csp.data.greeks import GreeksCalculator
from csp.data.manager import DataManager
from csp.storage import build_storage_backend
from csp.trading.execution import ExecutionEngine
from csp.trading.risk import RiskManager
from csp.trading.metadata import StrategyMetadataStore
from csp.trading.portfolio import print_portfolio_status
from csp.trading.liquidation import liquidate_all_holdings

from covered_call.config import CoveredCallConfig
from covered_call.store import WheelPositionStore
from covered_call.manager import CoveredCallManager

print("Imports OK")
# Out:
# Imports OK

# %%
# Configuration
N_TEST_TICKERS = 3       # how many random S&P 500 stocks to buy
SHARES_PER_TICKER = 100  # must be >= 100 for 1 CC contract

cc_config = CoveredCallConfig(
    enabled=True,
    cc_strike_mode="delta",     # try: "delta", "min_delta", "pct_change", "min_pct_change", "min_daily_return"
    cc_strike_delta=0.30,
    cc_min_dte=1,
    cc_max_dte=10,              # wider range for testing (more contracts available)
    cc_verbose=True,            # detailed diagnostics when no contracts found
)

config = StrategyConfig(
    paper_trading=True,
    entry_order_type="market",   # market orders for reliable fills during testing
    covered_call_config=cc_config,
    print_mode="verbose",
)

print(f"CC config: mode={cc_config.cc_strike_mode}, delta={cc_config.cc_strike_delta}, "
      f"DTE=[{cc_config.cc_min_dte}, {cc_config.cc_max_dte}]")
print(f"CC verbose diagnostics: {cc_config.cc_verbose}")
print(f"Universe: {len(config.ticker_universe)} S&P 500 symbols")
print(f"Will buy {SHARES_PER_TICKER} shares of {N_TEST_TICKERS} random tickers")

# %%
# Connect & Initialize
alpaca = AlpacaClientManager(paper=config.paper_trading)
vix_fetcher = VixDataFetcher()
greeks_calc = GreeksCalculator()
data_manager = DataManager(alpaca, config)
execution = ExecutionEngine(alpaca, config)
risk_manager = RiskManager(config)

storage = build_storage_backend(config)
metadata = StrategyMetadataStore(path="strategy_metadata.json", backend=storage)

wheel_store = WheelPositionStore(path="wheel_positions_test.json", backend=storage)

cc_manager = CoveredCallManager(
    cc_config=cc_config,
    strategy_config=config,
    store=wheel_store,
    data_manager=data_manager,
    execution=execution,
    risk_manager=risk_manager,
    metadata_store=metadata,
    alpaca_manager=alpaca,
)

current_vix = vix_fetcher.get_current_vix()
print(f"Alpaca connected (paper={alpaca.paper})")
print(f"VIX: {current_vix:.2f}")
print(f"CC Manager ready")
# Out:
# Alpaca connected (paper=True)
# VIX: 19.45
# CC Manager ready

# %%
# Portfolio status before test
print_portfolio_status(alpaca)
# Out:
# Alpaca Account Information
# ================================================================================
# Account status:              AccountStatus.ACTIVE
# Cash available:              $932,561.24
# Buying power (with margin):  $3,423,810.88
# Portfolio value:             $1,006,983.25
# Options trading level:       3
# Trading blocked:             False
#
# Current Positions (8):
#   Symbol                    Qty Side       Strike        Entry        Current      Mkt Value     Unreal P/L   Collateral
#   ------------------------------------------------------------------------------------------------------------------------
#   EQR                       100 long   $     0.00 $      63.18 $        63.08 $     6,307.50 $       -10.84 $       0.00
#   EVRG                      100 long   $     0.00 $      80.58 $        79.76 $     7,976.00 $       -82.00 $       0.00
#   EW                        100 long   $     0.00 $      78.78 $        78.72 $     7,872.00 $        -5.84 $       0.00
#   HWM                       100 long   $     0.00 $     252.96 $       257.87 $    25,786.50 $       490.50 $       0.00
#   SNDK260227P00550000        -1 short  $   550.00 $       6.80 $         5.90 $      -590.00 $        90.00 $  55,000.00
#   VZ                        100 long   $     0.00 $      48.83 $        48.87 $     4,887.01 $         3.73 $       0.00
#   WDC260227P00260000         -3 short  $   260.00 $       4.25 $         3.25 $      -975.00 $       300.00 $  78,000.00
#   WM                        100 long   $     0.00 $     233.95 $       231.58 $    23,158.00 $      -237.00 $       0.00
#
#   Total collateral tied up: $133,000.00
#   Available cash (after collateral): $799,561.24
#
# Open Orders: None
#
# Recent Order History (last 7 days, 100 orders):
#   Time                 Symbol               Side        Qty Type     Status          Avg Price
#   --------------------------------------------------------------------------------------------------------------
#   2026-02-19 22:23:34  EW                   buy         100 market   filled             $78.78
#   2026-02-19 22:23:34  EQR                  buy         100 market   filled             $63.18
#   2026-02-19 22:23:34  VZ                   buy         100 market   filled             $48.83
#   2026-02-19 22:23:13  HWM                  buy         100 market   filled            $252.96
#   2026-02-19 22:23:13  WM                   buy         100 market   filled            $233.95
#   2026-02-19 22:23:13  EVRG                 buy         100 market   filled             $80.58
#   2026-02-19 14:42:13  MU260227P00367500    sell          2 limit    filled              $5.20
#   2026-02-19 14:42:09  MU260227P00367500    sell          2 limit    canceled              N/A
#   2026-02-19 14:42:05  MU260227P00367500    sell          2 limit    canceled              N/A
#   2026-02-18 16:48:24  STX260227P00375000   buy           2 limit    filled              $5.50
#   2026-02-18 16:48:20  STX260227P00375000   buy           2 limit    canceled              N/A
#   2026-02-18 16:48:16  STX260227P00375000   buy           2 limit    canceled              N/A
#   2026-02-18 14:31:01  WDC260227P00260000   sell          3 market   filled              $4.25
#   2026-02-17 20:49:59  SNDK260220P00525000  sell          1 market   filled              $2.55
#   2026-02-17 20:49:57  STX260227P00375000   sell          2 market   filled              $5.80
#   2026-02-17 20:49:55  NEM260220P00110000   sell          5 market   filled              $0.61
#   2026-02-17 20:41:01  WDC260227P00247500   buy           4 market   filled              $5.10
#   2026-02-17 20:41:01  STX260227P00375000   buy           2 market   filled              $7.30
#   2026-02-17 20:41:01  SNDK260220P00525000  buy           1 market   filled              $3.40
#   2026-02-17 20:41:01  NEM260220P00110000   buy           5 market   filled              $0.73
#   ... and 80 more orders

# %% [markdown]
# ## Buy Test Shares
#
# Randomly select tickers from the S&P 500 and buy 100 shares of each.

# %%
# Screen tickers for CC-compatible options (calls on both upcoming Fridays)
from universe_screener.main import screen_tickers, get_next_fridays
from universe_screener.universe import get_combined_universe

universe = get_combined_universe()

# Use sample for interactive testing (full universe takes ~3 min)
results = screen_tickers(universe, data_manager.options_fetcher, sample_size=50)

pass_tickers = results["pass"]
test_tickers = random.sample(pass_tickers, min(N_TEST_TICKERS, len(pass_tickers)))
print(f"\nSelected for test: {test_tickers}")

# %%
# Buy shares of screened tickers (test_tickers selected in previous cell)
print(f"Buying {SHARES_PER_TICKER} shares of: {test_tickers}")
print()

buy_orders = []
for ticker in test_tickers:
    try:
        order_request = MarketOrderRequest(
            symbol=ticker,
            qty=SHARES_PER_TICKER,
            side=OrderSide.BUY,
            time_in_force=TimeInForce.DAY,
        )
        order = alpaca.trading_client.submit_order(order_request)
        print(f"  BUY {ticker}: {SHARES_PER_TICKER} shares — order {order.id} ({order.status.value})")
        buy_orders.append((ticker, str(order.id)))
    except Exception as e:
        print(f"  FAILED {ticker}: {e}")

print(f"\nSubmitted {len(buy_orders)} buy orders")

# %%
# Wait for fills and verify
print("Waiting 5s for order fills...")
time.sleep(5)

positions = alpaca.trading_client.get_all_positions()
stock_positions = [
    p for p in positions
    if not (any(c.isdigit() for c in p.symbol) and len(p.symbol) > 10)
]

print(f"\nStock positions ({len(stock_positions)}):")
for p in stock_positions:
    side = p.side.value if hasattr(p.side, 'value') else str(p.side)
    print(f"  {p.symbol:<8} qty={float(p.qty):>6.0f}  side={side:<6} "
          f"avg_entry=${float(p.avg_entry_price):>8.2f}  current=${float(p.current_price):>8.2f}")
# Out:
# Waiting 5s for order fills...
#
# Stock positions (9):
#   EQR      qty=   100  side=long   avg_entry=$   63.18  current=$   63.08
#   EVRG     qty=   100  side=long   avg_entry=$   80.58  current=$   79.76
#   EW       qty=   100  side=long   avg_entry=$   78.78  current=$   78.72
#   FCX      qty=   100  side=long   avg_entry=$   62.64  current=$   62.62
#   HWM      qty=   100  side=long   avg_entry=$  252.96  current=$  257.87
#   MAR      qty=   100  side=long   avg_entry=$  346.91  current=$  346.56
#   SLB      qty=   100  side=long   avg_entry=$   50.88  current=$   50.88
#   VZ       qty=   100  side=long   avg_entry=$   48.83  current=$   48.88
#   WM       qty=   100  side=long   avg_entry=$  233.95  current=$  231.55

# %% [markdown]
# ## CC Detection & Entry
#
# Test the covered call manager's ability to:
# 1. Detect stock positions from Alpaca
# 2. Create wheel position entries
# 3. Select and sell covered calls

# %%
# Step 1: Detect stock positions
new_count = await cc_manager._detect_stock_positions()
print(f"\nDetected {new_count} new stock position(s)")
# Out:
#   CC: Detected EQR — 100 shares @ $63.18 (source: alpaca_position)
#   CC: Detected EVRG — 100 shares @ $80.58 (source: alpaca_position)
#   CC: Detected EW — 100 shares @ $78.78 (source: alpaca_position)
#   CC: Detected FCX — 100 shares @ $62.64 (source: alpaca_position)
#   CC: Detected HWM — 100 shares @ $252.96 (source: alpaca_position)
#   CC: Detected MAR — 100 shares @ $346.91 (source: alpaca_position)
#   CC: Detected SLB — 100 shares @ $50.88 (source: alpaca_position)
#   CC: Detected VZ — 100 shares @ $48.83 (source: alpaca_position)
#   CC: Detected WM — 100 shares @ $233.95 (source: alpaca_position)
#
# Detected 9 new stock position(s)

# %%
# Inspect wheel store
print("Wheel Positions:")
print("=" * 80)
for sym, pos in wheel_store.get_active().items():
    print(f"  {sym}:")
    print(f"    Shares:     {pos['shares']}")
    print(f"    Cost basis: ${pos['cost_basis']:.2f}")
    print(f"    Source:     {pos['source']}")
    print(f"    Status:     {pos['status']}")
    print(f"    CC rounds:  {pos['cc_rounds']}")
    print(f"    Current CC: {pos['current_cc']}")
    print()
# Out:
# Wheel Positions:
# ================================================================================
#   EQR:
#     Shares:     100
#     Cost basis: $63.18
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None
#
#   EVRG:
#     Shares:     100
#     Cost basis: $80.58
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None
#
#   EW:
#     Shares:     100
#     Cost basis: $78.78
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None
#
#   FCX:
#     Shares:     100
#     Cost basis: $62.64
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None
#
#   HWM:
#     Shares:     100
#     Cost basis: $252.96
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None
#
#   MAR:
#     Shares:     100
#     Cost basis: $346.91
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None
#
#   SLB:
#     Shares:     100
#     Cost basis: $50.88
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None
#
#   VZ:
#     Shares:     100
#     Cost basis: $48.83
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None
#
#   WM:
#     Shares:     100
#     Cost basis: $233.95
#     Source:     alpaca_position
#     Status:     awaiting_cc_entry
#     CC rounds:  0
#     Current CC: None

# %%
# Step 2: Run a full CC cycle (detection + entry)
current_vix = vix_fetcher.get_current_vix()
print(f"VIX: {current_vix:.2f}")
print()

cc_summary = await cc_manager.run_cycle(current_vix)
print(f"\nCC Cycle Summary: {cc_summary}")
# Out:
# VIX: 18.91
#
#
#   CC Manager: 9 active wheel position(s)
#   CC: No call contracts available for EQR
#   CC: No call contracts available for EVRG
#   CC: No call contracts available for EW
#   CC TERMINATION (FCX): Strike recovery achieved
#     Best CC strike: $70.00 >= cost basis: $62.64
#   Selling 100 shares of FCX @ ~$62.56
#     Shares sold @ $62.64
#   CC TERMINATION (HWM): Strike recovery achieved
#     Best CC strike: $267.50 >= cost basis: $252.96
#   Selling 100 shares of HWM @ ~$257.39
#     Shares sold @ $257.88
#   CC TERMINATION (MAR): Strike recovery achieved
#     Best CC strike: $360.00 >= cost basis: $346.91
#   Selling 100 shares of MAR @ ~$346.55
#     Shares sold @ $346.58
#   CC TERMINATION (SLB): Strike recovery achieved
#     Best CC strike: $57.00 >= cost basis: $50.88
#   Selling 100 shares of SLB @ ~$50.83
#     Shares sold @ $50.87
#   CC TERMINATION (VZ): Strike recovery achieved
#     Best CC strike: $55.00 >= cost basis: $48.83
#   Selling 100 shares of VZ @ ~$48.85
#     Shares sold @ $48.89
#   CC: No call contracts available for WM
#
# CC Cycle Summary: {'cc_detected': 0, 'cc_entered': 0, 'cc_exited': 0, 'cc_terminated': 5}

# %%
# Inspect results after CC entry
print("Wheel Positions (after CC entry):")
print("=" * 80)
for sym, pos in wheel_store.get_active().items():
    print(f"  {sym}:")
    print(f"    Status:      {pos['status']}")
    print(f"    Cost basis:  ${pos['cost_basis']:.2f}")
    print(f"    CC premiums: ${pos['total_cc_premiums']:.2f}")
    cc = pos.get('current_cc')
    if cc:
        print(f"    Active CC:   {cc['option_symbol']}")
        print(f"      Strike:    ${cc['strike']:.2f}")
        print(f"      Premium:   ${cc['entry_premium']:.2f}")
        print(f"      Qty:       {cc['quantity']}")
        print(f"      Expiry:    {cc['expiration']}")
    else:
        print(f"    Active CC:   None (no contracts available?)")
    print()

# %% [markdown]
# ## Monitoring & Cleanup

# %%
# Run another cycle to exercise monitoring (should show CCs as healthy)
current_vix = vix_fetcher.get_current_vix()
print(f"VIX: {current_vix:.2f}")
print()

cc_summary = await cc_manager.run_cycle(current_vix)
print(f"\nMonitoring Cycle Summary: {cc_summary}")

# %%
# Cleanup: liquidate everything
print("Liquidating all holdings...")
liquidate_all_holdings(alpaca)

# Clear test wheel store
for sym in list(wheel_store.positions.keys()):
    wheel_store.terminate(sym, reason="test_cleanup")
print("\nWheel store cleaned up")
print("Done!")
